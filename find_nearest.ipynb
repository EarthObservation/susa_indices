# %% [markdown]
# # Loop all crop types
#
# (and save CSV)
#
# keep: id_17
#
# | new columns: | | | | | | | | |
# | :- | :- | :- | :- | :- | :- | :- | :- | :- |
# | | dist_18 | id_18-0 | id_18-1 | id_18-2 | dist_19 | id_19-0 | id_19-1 | id_19-2 |

# %%
# %%time

# Import modules
import geopandas as gpd
import pandas as pd
import numpy as np
from sklearn.neighbors import BallTree

# Import shape files
clean_17 = gpd.read_file(".\\poljine_SHP\\ZV2017_d96tm_clean_ids.shp")
clean_18 = gpd.read_file(".\\poljine_SHP\\ZV2018_d96tm_clean_ids.shp")
clean_19 = gpd.read_file(".\\poljine_SHP\\KMRS2019_d96tm_clean_ids.shp")
# Out:
# Wall time: 3min 2s

# %%
# %%time

# (0) Select the year for processing & and set number of closest neighbours
year = 2018
no_near = 3

# (1) Create Df copy for output and
output = clean_17.copy()

# (2) add new columns for that will be use for finding nearest neighbours
ktree_labels = ["dist0"] + [f"near{n}" for n in range(no_near)]
for lb in ktree_labels:
    output[lb] = None
    
# (3) Tidy (remove unneeded columns)
output = output.drop(columns=["RABA_ID", "POVR_GERK_"])
output = output.drop(output.loc[:, "OBRAZEC" : "REGIJA"].columns, axis=1)

output.head(2)
# Out:
# Wall time: 800 ms
#    id_17  GERK_PID  POLJINA_ID SIFRA_KMRS  \
# 0      0   2537988     2104906        801
# 1      1   2537988     2104908        005
#
#                                             geometry dist0 near0 near1 near2
# 0  POLYGON ((547508.347 86829.736, 547545.426 868...  None  None  None  None
# 1  POLYGON ((547497.850 86785.076, 547578.847 867...  None  None  None  None

# %% [markdown]
# Now we need to filter the data. We are only interseted in the crop types that have at least 1000 instances for each year.
#
# This cell is a little bigger, just so we can see which crop types were excluded:

# %%
# %%time

threshold = 1000

print(f"Removing crop types with less than {threshold} occurances in 2017:\n--")

# Get statistics on KMRS values (crop type)
kmrs_list = clean_17.SIFRA_KMRS.value_counts()
# Only select values that have more than 1000 occurances 
k_list = kmrs_list[kmrs_list <= threshold].index.to_list()  # Excluded indices
kmrs_list = kmrs_list[kmrs_list > threshold].index.to_list()
print(f"{len(kmrs_list)} elements:\n {kmrs_list}")

for k in k_list:
    rem_17 = str(clean_17.SIFRA_KMRS.value_counts().loc[k])

    try:
        rem_18 = str(clean_18.SIFRA_KMRS.value_counts().loc[k])
    except:
        rem_18 = "0"

    try:
        rem_19 = str(clean_19.SIFRA_KMRS.value_counts().loc[k])
    except:
        rem_19 = "0"
    print(f"Removed {k} | {rem_17} instances in 2017 | {rem_18} instances in 2018 | {rem_19} instances in 2019")

# Check if all croptypes from kmrs_list are available in 2018 and 2019, remove if not
kmrs_18 = clean_18.SIFRA_KMRS.value_counts()
kmrs_18 = kmrs_18[kmrs_18 > threshold].index.to_list()
kmrs_list_a = kmrs_list.copy()  # Had to do this to not prevent skipping of elements in the list
for k in kmrs_list:
    if k not in kmrs_18:
        kmrs_list_a.remove(k)
        rem_17 = clean_17.SIFRA_KMRS.value_counts().loc[k]
        
        try:
            rem_18 = clean_18.SIFRA_KMRS.value_counts().loc[k]
        except:
            rem_18 = 0
        
        try:
            rem_19 = clean_19.SIFRA_KMRS.value_counts().loc[k]
        except:
            rem_19 = 0
        
        print(f"Removed {k} | {rem_17} instances in 2017 | {rem_18} instances in 2018 | {rem_19} instances in 2019")

print(f"{len(kmrs_list_a)} elements:\n {kmrs_list_a}")

kmrs_19 = clean_19.SIFRA_KMRS.value_counts()
kmrs_19 = kmrs_19[kmrs_19 > threshold].index.to_list()
kmrs_list_b = kmrs_list_a.copy()
for k in kmrs_list_a:
    if k not in kmrs_19:
        kmrs_list_b.remove(k)
        rem_17 = str(clean_17.SIFRA_KMRS.value_counts().loc[k])
        
        try:
            rem_18 = str(clean_18.SIFRA_KMRS.value_counts().loc[k])
        except:
            rem_18 = "0"
        
        try:
            rem_19 = str(clean_19.SIFRA_KMRS.value_counts().loc[k])
        except:
            rem_19 = "0"
        
        print(f"Removed {k} | {rem_17} instances in 2017 | {rem_18} instances in 2018 | {rem_19} instances in 2019")

print(f"{len(kmrs_list_b)} elements:\n {kmrs_list_b}")

kmrs_list = kmrs_list_b.copy()

# append 004 - ajda (see notes in the notebook below)
kmrs_list.append("004")
# Out:
# Removing crop types with less than 1000 occurances in 2017:
# --
# 34 elements:
#  ['204', '005', '801', '809', '006', '100', '699', '203', '201', '208', '807', '013', '112', '405', '207', '020', '814', '206', '004', '402', '222', '555', '611', '111', '008', '506', '030', '811', '802', '812', '009', '800', '026', '803']
# Removed 808 | 881 instances in 2017 | 841 instances in 2018 | 653 instances in 2019
# Removed 001 | 877 instances in 2017 | 578 instances in 2018 | 591 instances in 2019
# Removed 033 | 854 instances in 2017 | 551 instances in 2018 | 469 instances in 2019
# Removed 706 | 820 instances in 2017 | 936 instances in 2018 | 874 instances in 2019
# Removed 900 | 661 instances in 2017 | 676 instances in 2018 | 660 instances in 2019
# Removed 631 | 545 instances in 2017 | 618 instances in 2018 | 709 instances in 2019
# Removed 027 | 450 instances in 2017 | 429 instances in 2018 | 478 instances in 2019
# Removed 014 | 442 instances in 2017 | 378 instances in 2018 | 23 instances in 2019
# Removed 621 | 429 instances in 2017 | 403 instances in 2018 | 373 instances in 2019
# Removed 625 | 424 instances in 2017 | 450 instances in 2018 | 437 instances in 2019
# Removed 012 | 390 instances in 2017 | 415 instances in 2018 | 428 instances in 2019
# Removed 114 | 384 instances in 2017 | 382 instances in 2018 | 158 instances in 2019
# Removed 010 | 379 instances in 2017 | 428 instances in 2018 | 155 instances in 2019
# Removed 047 | 305 instances in 2017 | 357 instances in 2018 | 0 instances in 2019
# Removed 113 | 288 instances in 2017 | 279 instances in 2018 | 10 instances in 2019
# Removed 623 | 285 instances in 2017 | 321 instances in 2018 | 310 instances in 2019
# Removed 219 | 276 instances in 2017 | 133 instances in 2018 | 79 instances in 2019
# Removed 042 | 236 instances in 2017 | 289 instances in 2018 | 0 instances in 2019
# Removed 612 | 236 instances in 2017 | 244 instances in 2018 | 247 instances in 2019
# Removed 007 | 212 instances in 2017 | 338 instances in 2018 | 249 instances in 2019
# Removed 651 | 212 instances in 2017 | 253 instances in 2018 | 254 instances in 2019
# Removed 703 | 203 instances in 2017 | 222 instances in 2018 | 230 instances in 2019
# Removed 103 | 198 instances in 2017 | 157 instances in 2018 | 29 instances in 2019
# Removed 643 | 193 instances in 2017 | 218 instances in 2018 | 221 instances in 2019
# Removed 024 | 182 instances in 2017 | 93 instances in 2018 | 142 instances in 2019
# Removed 833 | 182 instances in 2017 | 108 instances in 2018 | 56 instances in 2019
# Removed 105 | 173 instances in 2017 | 190 instances in 2018 | 7 instances in 2019
# Removed 657 | 171 instances in 2017 | 206 instances in 2018 | 217 instances in 2019
# Removed 702 | 162 instances in 2017 | 154 instances in 2018 | 149 instances in 2019
# Removed 101 | 148 instances in 2017 | 123 instances in 2018 | 98 instances in 2019
# Removed 404 | 132 instances in 2017 | 114 instances in 2018 | 109 instances in 2019
# Removed 109 | 132 instances in 2017 | 234 instances in 2018 | 271 instances in 2019
# Removed 632 | 128 instances in 2017 | 148 instances in 2018 | 164 instances in 2019
# Removed 624 | 108 instances in 2017 | 116 instances in 2018 | 117 instances in 2019
# Removed 704 | 102 instances in 2017 | 90 instances in 2018 | 79 instances in 2019
# Removed 825 | 101 instances in 2017 | 62 instances in 2018 | 46 instances in 2019
# Removed 777 | 92 instances in 2017 | 142 instances in 2018 | 69 instances in 2019
# Removed 019 | 77 instances in 2017 | 141 instances in 2018 | 138 instances in 2019
# Removed 644 | 75 instances in 2017 | 91 instances in 2018 | 99 instances in 2019
# Removed 707 | 67 instances in 2017 | 71 instances in 2018 | 64 instances in 2019
# Removed 049 | 67 instances in 2017 | 58 instances in 2018 | 11 instances in 2019
# Removed 044 | 63 instances in 2017 | 46 instances in 2018 | 0 instances in 2019
# Removed 116 | 59 instances in 2017 | 110 instances in 2018 | 83 instances in 2019
# Removed 652 | 58 instances in 2017 | 63 instances in 2018 | 70 instances in 2019
# Removed 653 | 55 instances in 2017 | 66 instances in 2018 | 63 instances in 2019
# Removed 028 | 50 instances in 2017 | 52 instances in 2018 | 40 instances in 2019
# Removed 735 | 44 instances in 2017 | 38 instances in 2018 | 31 instances in 2019
# Removed 036 | 43 instances in 2017 | 41 instances in 2018 | 49 instances in 2019
# Removed 000 | 42 instances in 2017 | 35 instances in 2018 | 38 instances in 2019
# Removed 678 | 40 instances in 2017 | 66 instances in 2018 | 73 instances in 2019
# Removed 835 | 35 instances in 2017 | 33 instances in 2018 | 28 instances in 2019
# Removed 003 | 35 instances in 2017 | 28 instances in 2018 | 23 instances in 2019
# Removed 737 | 33 instances in 2017 | 41 instances in 2018 | 44 instances in 2019
# Removed 108 | 30 instances in 2017 | 32 instances in 2018 | 19 instances in 2019
# Removed 505 | 30 instances in 2017 | 11 instances in 2018 | 0 instances in 2019
# Removed 642 | 28 instances in 2017 | 27 instances in 2018 | 34 instances in 2019
# Removed 104 | 28 instances in 2017 | 34 instances in 2018 | 0 instances in 2019
# Removed 804 | 28 instances in 2017 | 68 instances in 2018 | 1 instances in 2019
# Removed 220 | 27 instances in 2017 | 37 instances in 2018 | 2 instances in 2019
# Removed 722 | 27 instances in 2017 | 30 instances in 2018 | 34 instances in 2019
# Removed 647 | 27 instances in 2017 | 29 instances in 2018 | 30 instances in 2019
# Removed 710 | 26 instances in 2017 | 13 instances in 2018 | 11 instances in 2019
# Removed 721 | 25 instances in 2017 | 22 instances in 2018 | 23 instances in 2019
# Removed 002 | 24 instances in 2017 | 18 instances in 2018 | 9 instances in 2019
# Removed 041 | 24 instances in 2017 | 24 instances in 2018 | 0 instances in 2019
# Removed 046 | 23 instances in 2017 | 14 instances in 2018 | 0 instances in 2019
# Removed 011 | 22 instances in 2017 | 36 instances in 2018 | 19 instances in 2019
# Removed 661 | 21 instances in 2017 | 30 instances in 2018 | 34 instances in 2019
# Removed 102 | 21 instances in 2017 | 23 instances in 2018 | 5 instances in 2019
# Removed 698 | 19 instances in 2017 | 25 instances in 2018 | 30 instances in 2019
# Removed 040 | 19 instances in 2017 | 29 instances in 2018 | 0 instances in 2019
# Removed 029 | 18 instances in 2017 | 22 instances in 2018 | 12 instances in 2019
# Removed 110 | 17 instances in 2017 | 6 instances in 2018 | 2 instances in 2019
# Removed 646 | 17 instances in 2017 | 16 instances in 2018 | 20 instances in 2019
# Removed 626 | 12 instances in 2017 | 8 instances in 2018 | 7 instances in 2019
# Removed 403 | 12 instances in 2017 | 23 instances in 2018 | 31 instances in 2019
# Removed 025 | 12 instances in 2017 | 24 instances in 2018 | 15 instances in 2019
# Removed 017 | 10 instances in 2017 | 3 instances in 2018 | 6 instances in 2019
# Removed 035 | 10 instances in 2017 | 18 instances in 2018 | 13 instances in 2019
# Removed 659 | 9 instances in 2017 | 14 instances in 2018 | 14 instances in 2019
# Removed 210 | 8 instances in 2017 | 4 instances in 2018 | 6 instances in 2019
# Removed 107 | 8 instances in 2017 | 11 instances in 2018 | 9 instances in 2019
# Removed 622 | 7 instances in 2017 | 6 instances in 2018 | 7 instances in 2019
# Removed 810 | 7 instances in 2017 | 10 instances in 2018 | 9 instances in 2019
# Removed 656 | 7 instances in 2017 | 7 instances in 2018 | 8 instances in 2019
# Removed 202 | 6 instances in 2017 | 22 instances in 2018 | 17 instances in 2019
# Removed 831 | 6 instances in 2017 | 6 instances in 2018 | 14 instances in 2019
# Removed 045 | 6 instances in 2017 | 19 instances in 2018 | 0 instances in 2019
# Removed 738 | 5 instances in 2017 | 2 instances in 2018 | 3 instances in 2019
# Removed 031 | 5 instances in 2017 | 1 instances in 2018 | 5 instances in 2019
# Removed 615 | 5 instances in 2017 | 7 instances in 2018 | 8 instances in 2019
# Removed 654 | 5 instances in 2017 | 4 instances in 2018 | 8 instances in 2019
# Removed 655 | 4 instances in 2017 | 4 instances in 2018 | 5 instances in 2019
# Removed 613 | 4 instances in 2017 | 4 instances in 2018 | 4 instances in 2019
# Removed 115 | 3 instances in 2017 | 4 instances in 2018 | 1 instances in 2019
# Removed 633 | 3 instances in 2017 | 4 instances in 2018 | 7 instances in 2019
# Removed 106 | 3 instances in 2017 | 0 instances in 2018 | 4 instances in 2019
# Removed 733 | 3 instances in 2017 | 1 instances in 2018 | 1 instances in 2019
# Removed 720 | 2 instances in 2017 | 3 instances in 2018 | 4 instances in 2019
# Removed 616 | 2 instances in 2017 | 2 instances in 2018 | 2 instances in 2019
# Removed 649 | 2 instances in 2017 | 2 instances in 2018 | 2 instances in 2019
# Removed 821 | 2 instances in 2017 | 4 instances in 2018 | 4 instances in 2019
# Removed 680 | 2 instances in 2017 | 5 instances in 2018 | 5 instances in 2019
# Removed 734 | 2 instances in 2017 | 2 instances in 2018 | 1 instances in 2019
# Removed 677 | 2 instances in 2017 | 2 instances in 2018 | 3 instances in 2019
# Removed 034 | 2 instances in 2017 | 3 instances in 2018 | 0 instances in 2019
# Removed 221 | 2 instances in 2017 | 1 instances in 2018 | 1 instances in 2019
# Removed 736 | 2 instances in 2017 | 3 instances in 2018 | 3 instances in 2019
# Removed 043 | 1 instances in 2017 | 0 instances in 2018 | 0 instances in 2019
# Removed 675 | 1 instances in 2017 | 3 instances in 2018 | 4 instances in 2019
# Removed 674 | 1 instances in 2017 | 1 instances in 2018 | 3 instances in 2019
# Removed 648 | 1 instances in 2017 | 1 instances in 2018 | 2 instances in 2019
# Removed 803 | 1006 instances in 2017 | 964 instances in 2018 | 715 instances in 2019
# 33 elements:
#  ['204', '005', '801', '809', '006', '100', '699', '203', '201', '208', '807', '013', '112', '405', '207', '020', '814', '206', '004', '402', '222', '555', '611', '111', '008', '506', '030', '811', '802', '812', '009', '800', '026']
# Removed 112 | 7125 instances in 2017 | 7280 instances in 2018 | 33 instances in 2019
# Removed 004 | 4009 instances in 2017 | 4173 instances in 2018 | 827 instances in 2019
# Removed 222 | 3262 instances in 2017 | 3154 instances in 2018 | 710 instances in 2019
# Removed 555 | 2765 instances in 2017 | 2549 instances in 2018 | 0 instances in 2019
# Removed 111 | 2468 instances in 2017 | 2595 instances in 2018 | 46 instances in 2019
# Removed 506 | 2220 instances in 2017 | 2331 instances in 2018 | 0 instances in 2019
# Removed 811 | 1922 instances in 2017 | 2281 instances in 2018 | 80 instances in 2019
# Removed 812 | 1613 instances in 2017 | 1578 instances in 2018 | 69 instances in 2019
# 25 elements:
#  ['204', '005', '801', '809', '006', '100', '699', '203', '201', '208', '807', '013', '405', '207', '020', '814', '206', '402', '611', '008', '030', '802', '009', '800', '026']
# Wall time: 46.4 s

# %% [markdown]
# In the end, we are left with 25 crop types as seen in from the final list above.
#
# Excluded were:
#
# | KMRS    | instances in 2017 | instances in 2018 | instances in 2019 | crop type |
# | :--     | :-:  | :-:  | :-: | :--- |
# | **803** | 1006 | 964  | 715 | pira (ozimna) |
# | **112** | 7125 | 7280 | 33  | krmna ogrščica (jara) |
# | ~~**004**~~ | ~~4009~~ | ~~4173~~ | ~~827~~ | ~~ajda~~ |
# | **222** | 3262 | 3154 | 710 | inkarnatka |
# | **555** | 2765 | 2549 | 0   | brez zahtevka |
# | **111** | 2468 | 2595 | 46  | bela gorjušica |
# | **506** | 2220 | 2331 | 0   | mešanica rastlin - naknadni posevek |
# | **811** | 1922 | 2281 | 80  | mešanice žit (ozimna) |
# | **812** | 1613 | 1578 | 69  | krmna ogrščica (ozimna) |
#
# > `004` was added back, because it has been already used in the Susa project (it got accidentaly filtered out becuse it had less tha 1000 samples in the year 2019)

# %% [markdown]
# We have now built a list of all valid crop-types.
#
# Next, we will search for nearest neighbours between two shapefiles. It includes the following steps:
#
# 1) FILTER THE DATA (have to do this for each KMRS type separately)
#
# 2) BUILD SPATIAL INDEX (based on centroids)
#
# 3) FIND CORESPONDING VALUES (and fill the 2017-20xx table)

# %%
# %%time

for kmrs in kmrs_list:
    """(1) FILTER"""
    # Filter dataframe to include only this crop type
    filter_17 = clean_17["SIFRA_KMRS"] == kmrs
    data_17 = clean_17[filter_17]
    # Make sure you have the right year for the right data frame
    if year == 2018:
        filter_18 = clean_18["SIFRA_KMRS"] == kmrs
        data_18 = clean_18[filter_18]
    elif year == 2019:
        filter_18 = clean_19["SIFRA_KMRS"] == kmrs
        data_18 = clean_19[filter_18]
    else:
        print(f"Wrong year selected: {year}")
    
    """(2) BUILD K-TREE"""
    # Calculate centroid and parse coordinates
    src_points = np.array(data_17.centroid.apply(lambda geom: (geom.x, geom.y)).to_list())
    candidates = np.array(data_18.centroid.apply(lambda geom: (geom.x, geom.y)).to_list())

    # Set this to 3 to find the 3 closest (parametrized, set above with inputs)
    k_neighbors = no_near

    # Create tree from the candidate points (make sure you use arithmetic distance)
    tree = BallTree(candidates, leaf_size=15)
    
    # Find closest points and distances
    distances, indices = tree.query(src_points, k=k_neighbors)
    
    """(3) POPULATE DATA FRAME WITH THE RESULTS"""
    # K-tree query returns indices in an array, which means we lost the indices from the original data frame (candidates)
    my_index = indices.flatten()
    # Find corresponding indices (make sure to have the correct year)
    id_year = f"id_{str(year)[-2:]}"  # either "id_18" or "id_19"
    new_ids = data_18[id_year].reset_index(drop=True).iloc[my_index].to_numpy()
    # Change back to original shape
    ids_18 = new_ids.reshape(indices.shape)
    
    # Populate the output data frame
    output.loc[filter_17, ktree_labels[0]] = distances[:, 0].tolist()
    output.loc[filter_17, ktree_labels[1:]] = ids_18.tolist()
# Out:
# Wall time: 1min 55s

# %%
# %%time

# SAVE CSV
output.drop(columns=["geometry"]).to_csv(f".\\results_ids\\ZV2017_nearest_ids_{str(year)[-2:]}_ajda.csv", index=False)
# Out:
# Wall time: 3.7 s

# %%
# %%time

# SAVE OUTPUT
output.to_file(f".\\results_ids\\ZV2017_nearest_ids_{str(year)[-2:]}_ajda.shp")
# Out:
# Wall time: 3min 34s
